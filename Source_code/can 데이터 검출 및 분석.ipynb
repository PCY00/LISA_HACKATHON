# %% [markdown]
# # 최종

# %%
from __future__ import print_function
from PCANBasic import *
import pandas as pd
import os
import datetime
import keyboard
import time

cols = ["No", "Time_Offset", "Type", "ID", "Data_Length", 'One', 'Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight']

def process_data(data_frame, file_path):
    start = 0
    start_time = None
    end_time = None

    for index, row in data_frame.iterrows():
        if row['ID'] == '043F' and row['Two'] == '40':
            start = 1
        elif start == 1 and row['ID'] == '0316':
            if row['Four'] >= '20':
                start_time = row['Time_Offset']
                break
        elif row['ID'] == '043F' and row['Two'] == '40':
            start = 0

    # 찾은 start_time 이후에 가장 작은 end_time을 찾음
    for index, row in data_frame.iterrows():
        if start == 1 and start_time is not None and row['Time_Offset'] > start_time + 1500:
            if end_time is None or row['Time_Offset'] < end_time:
                end_time = row['Time_Offset']

    print("=========================================================================")
    print("0316 & 043F / P기어일 때 RPM 올라가는 이벤트")
    print(f"Start Time: {start_time}")
    print(f"End Time: {end_time}")
    print("=========================================================================")


    start = 0
    start_time = None
    end_time = None

    for index, row in data_frame.iterrows():
        if row['ID'] == '0440' and row['Three'] == '00':
            start = 1
            start_time = row['Time_Offset']
        elif start == 1 and row['ID'] == '0316':
            if row['Four'] > '14':
                end_time = row['Time_Offset']
                if end_time > start_time + 1500:
                    break
        elif row['ID'] == '0440' and row['Three'] == '00':
            start = 0

    print("=========================================================================")
    print("0440 & 0316 / speed가 0일 때 RPM 10진수 20이상 이상일 때 ")
    print(f"Start Time: {start_time}")
    print(f"End Time: {end_time}")
    print("=========================================================================")

    start = 0
    start_time = None
    end_time = None

    for index, row in data_frame.iterrows():
        if row['ID'] == '043F' and row['Two'] == '46':
            start = 1
            start_time = row['Time_Offset']
        elif start == 1 and row['ID'] == '0316':
            if row['Four'] > '16':
                end_time = row['Time_Offset']
                if end_time > start_time + 1500:
                    break
        elif row['ID'] == '0440' and row['Three'] == '00':
            start = 0

    print("=========================================================================")
    print("043F & 0316 / N 기어일 때, RPM이 높아지면 안됨")
    print(f"Start Time: {start_time}")
    print(f"End Time: {end_time}")
    print("=========================================================================")


    start = 0
    start_time = None
    end_time = None

    for index, row in data_frame.iterrows():
        if row['ID'] == '043F' and row['Two'] == '45':
            start = 1
        elif start == 1 and row['ID'] == '0018':
            if row['One'] == '30':
                start_time = row['Time_Offset']
                break
        elif row['ID'] == '043F' and row['Two'] == '45':
            start = 0

    # 찾은 start_time 이후에 가장 작은 end_time을 찾음
    for index, row in data_frame.iterrows():
        if start == 1 and start_time is not None and row['Time_Offset'] > start_time + 1500:
            if end_time is None or row['Time_Offset'] < end_time:
                end_time = row['Time_Offset']

    print("=========================================================================")
    print("0018 & 043F / 운전자석 문이 열여있을 때 D기어 이면 안됨")
    print(f"Start Time: {start_time}")
    print(f"End Time: {end_time}")
    print("=========================================================================")


    start = 0
    start_time = None
    end_time = None

    for index, row in data_frame.iterrows():
        if row['ID'] == '043F' and row['Two'] == '47':
            start = 1
        elif start == 1 and row['ID'] == '0018':
            if row['One'] == '30':
                start_time = row['Time_Offset']
                break
        elif row['ID'] == '043F' and row['Two'] == '47':
            start = 0

    # 찾은 start_time 이후에 가장 작은 end_time을 찾음
    for index, row in data_frame.iterrows():
        if start == 1 and start_time is not None and row['Time_Offset'] > start_time + 1500:
            if end_time is None or row['Time_Offset'] < end_time:
                end_time = row['Time_Offset']

    print("=========================================================================")
    print("043F & 0018 / R기어 일때 운전자석 문 열려있으면 안됨")
    print(f"Start Time: {start_time}")
    print(f"End Time: {end_time}")
    print("=========================================================================")


    # Sort the filtered data by 'Time_Offset' column
    filtered_data = data_frame.sort_values('Time_Offset')

    start_time = None
    end_time = None
    time_threshold = 1500  # Threshold of 1500 for time difference

    for index, row in data_frame.iterrows():
        if start_time is None:
            start_time = row['Time_Offset']
        elif row['Time_Offset'] - start_time >= time_threshold:
            end_time = row['Time_Offset']
            break

    # Update end_time to the smallest value that satisfies the condition
    if end_time is None:
        end_time = data_frame['Time_Offset'].iloc[-1]

    print("=========================================================================")
    print("0018 / 시트벨트가 해제인데 장착으로 인식할 수 없다")
    print(f"Start Time: {start_time}")
    print(f"End Time: {end_time}")
    print("=========================================================================")


    start = 0
    start_time = None
    end_time = None

    for index, row in data_frame.iterrows():
        if row['ID'] == '0018' and row['One'] == '28':
            start = 1
        elif start == 1 and row['ID'] == '043F':
            if row['Two'] == '45':
                start_time = row['Time_Offset']
                break
        elif row['ID'] == '0018' and row['One'] == '28':
            start = 0

    # 찾은 start_time 이후에 가장 작은 end_time을 찾음
    for index, row in data_frame.iterrows():
        if start == 1 and start_time is not None and row['Time_Offset'] > start_time + 1500:
            if end_time is None or row['Time_Offset'] < end_time:
                end_time = row['Time_Offset']

    print("=========================================================================")
    print("0018 & 043F / 밸트 미착용일 때 기어 D")
    print(f"Start Time: {start_time}")
    print(f"End Time: {end_time}")
    print("=========================================================================")


    start = 0
    start_time = None
    end_time = None

    for index, row in data_frame.iterrows():
        if row['ID'] == '0018' and row['One'] == '28':
            start = 1
        elif start == 1 and row['ID'] == '043F':
            if row['Two'] == '47':
                start_time = row['Time_Offset']
                break
        elif row['ID'] == '0018' and row['One'] == '28':
            start = 0

    # 찾은 start_time 이후에 가장 작은 end_time을 찾음
    for index, row in data_frame.iterrows():
        if start == 1 and start_time is not None and row['Time_Offset'] > start_time + 1500:
            if end_time is None or row['Time_Offset'] < end_time:
                end_time = row['Time_Offset']

    print("=========================================================================")
    print("0018 & 043F / 밸트 미착용일 때 기어 R")
    print(f"Start Time: {start_time}")
    print(f"End Time: {end_time}")
    print("=========================================================================")


    start = 0
    start_time = None
    end_time = None

    for index, row in data_frame.iterrows():
        if row['ID'] == '0018' and row['Eight'] == '10':
            start = 1
        elif start == 1 and row['ID'] == '0440':
            if row['Three'] >= '10':
                start_time = row['Time_Offset']
                break
        elif row['ID'] == '0018' and row['Eight'] == '10':
            start = 0

    # 찾은 start_time 이후에 가장 작은 end_time을 찾음
    for index, row in data_frame.iterrows():
        if start == 1 and start_time is not None and row['Time_Offset'] > start_time + 1500:
            if end_time is None or row['Time_Offset'] < end_time:
                end_time = row['Time_Offset']

    print("=========================================================================")
    print("0018 & 0440 / 벨트 off 일 때 속도 증가 x")
    print(f"Start Time: {start_time}")
    print(f"End Time: {end_time}")
    print("=========================================================================")
    
    print(f"The source of the processed data is {file_path}\n")

if __name__ == "__main__":
    dataset_type = "Sensing"
    dataset_dir = "Dataset"
    processed_files = set()  # To keep track of processed files

    # Create the Dataset directory if it doesn't exist
    if not os.path.exists(dataset_dir):
        print("Dataset directory does not exist.")
        sys.exit()

    while True:
        file_list = os.listdir(dataset_dir)

        file_list.sort()

        for file_name in file_list:
            if file_name.endswith(".txt") and file_name.startswith(f"{dataset_type} Dataset"):
                file_path = os.path.join(dataset_dir, file_name)

                # Check if the file exists and if it has been processed
                if os.path.exists(file_path) and file_path not in processed_files:
                    print(f"Processing file: {file_path}")

                    data_frame = pd.read_csv(file_path, delimiter='\t')
                    process_data(data_frame, file_path)

                    processed_files.add(file_path)

                time.sleep(1)
# Out:
# Processing file: Dataset\Sensing Dataset-00001.txt
# ...
# 0316 & 043F / P기어일 때 RPM 올라가는 이벤트
# Start Time: None
# End Time: None
# ...
# 0440 & 0316 / speed가 0일 때 RPM 10진수 20이상 이상일 때
# Start Time: 40.96
# End Time: None
# ...
# 043F & 0316 / N 기어일 때, RPM이 높아지면 안됨
# Start Time: None
# End Time: None
# ...
# 0018 & 043F / 운전자석 문이 열여있을 때 D기어 이면 안됨
# Start Time: None
# End Time: None
# ...
# 043F & 0018 / R기어 일때 운전자석 문 열려있으면 안됨
# Start Time: None
# End Time: None
# ...
# 0018 / 시트벨트가 해제인데 장착으로 인식할 수 없다
# Start Time: 0.0
# End Time: 47.146
# ...
# 0018 & 043F / 밸트 미착용일 때 기어 D
# Start Time: None
# End Time: None
# ...
# 0018 & 043F / 밸트 미착용일 때 기어 R
# Start Time: None
# End Time: None
# ...
# 0018 & 0440 / 벨트 off 일 때 속도 증가 x
# Start Time: None
# End Time: None
# ...
# The source of the processed data is Dataset\Sensing Dataset-00001.txt
#
# Processing file: Dataset\Sensing Dataset-00002.txt
# ...
# 0316 & 043F / P기어일 때 RPM 올라가는 이벤트
# Start Time: None
# End Time: None
# ...
# 0440 & 0316 / speed가 0일 때 RPM 10진수 20이상 이상일 때
# Start Time: 39.21
# End Time: None
# ...
